# %%
num1 =int(input("Enter 1st number: "))
num2 =int(input("Enter 2nd number: "))
operator=input("Enter the operator (+, -, *, /): ")

if operator== '+':
    res=num1 + num2
elif operator== '-':
    res=num1-num2
elif operator=='*':
    res=num1*num2
elif operator=='/':
    res=num1/num2
else:
    res="wrong input"

print("The result is", res)
# Out:
# The result is 4.583333333333333

# %%
for i in range(1, 11):
 if i>1:
    for j in range(2, i):
        if i%j == 0:
            break
    else:
        print(i, end=" ")
# Out:
# 2 3 5 7

# %%
for i in range(5):
    for j in range(i+1):
        print("*", end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****
